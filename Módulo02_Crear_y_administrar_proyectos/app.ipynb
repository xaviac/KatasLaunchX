# %%
from datetime import *
from dateutil.relativedelta import *
now = datetime.now()
print(now)

now = now + relativedelta(months=1,weeks=1,hour=10)

print(now)
# Out:
# 2022-02-06 08:45:44.456219
# 2022-03-13 10:45:44.456219

# %% [markdown]
# ### Ejercicios y Kata del módulo 3

# %%
a = 97
b = 55

if a < b:
    print(b)

# %%
a = 93
b = 27

if a >= b:
    print(a)
# Out:
# 93

# %%
a = 24
b = 44

if a <= 0:
    print(a)
print(b)
# Out:
# 44

# %%
a = 93
b = 27

if a >= b:
    print(a)
else:
    print(b)
# Out:
# 93

# %%
a = 93
b = 27
if a > b:
    print("a es mayor que b")
elif a < b:
    print("a es menor que b")
else: 
    print ("a es igual que b")
# Out:
# a es mayor que b

# %%
a = 16
b = 25
c = 27
if a > b:
    if b > c:
        print ("a es mayor que b y b es mayor que c")
    else: 
        print ("a es mayor que b y menor que c")
elif a == b:
    print ("a es igual que b")
else:
    print ("a es menor que b")
# Out:
# a es menor que b

# %%
a = 23
b = 34
if a == 34 or b == 34:
    print(a + b)
# Out:
# 57

# %%
a = 23
b = 34
if a == 34 and b == 34:
    print (a + b)

# %%
velAsteroide = 49

if velAsteroide > 25:
    print("Alerta! Se aproxima un asteroide demasiado rápido a la Tierra a una velocidad de " + str(velAsteroide) + "km/s")
# Out:
# Alerta! Se aproxima un asteroide demasiado rápido a la Tierra a una velocidad de 49km/s

# %%
velAsteroide = 49

if velAsteroide > 25:
    print("Alerta! Se aproxima un asteroide demasiado rápido a la Tierra a una velocidad de " + str(velAsteroide) + " km/s")
# Out:
# Alerta! Se aproxima un asteroide demasiado rápido a la Tierra a una velocidad de 49 km/s

# %%
velAsteroide = 19

if velAsteroide >= 20:
    print("Busquen el asteroide en en cielo")
elif velAsteroide == 20:
    print("Mantengase alertas.")
else:
    print("Todo esta en calma")
# Out:
# Todo esta en calma

# %%
tamAsteroide = 18
velAsteroide

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el ateroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 25
velAsteroide

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el ateroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 26
velAsteroide

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el ateroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 26
velAsteroide

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el ateroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 26
velAsteroide = 0

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el ateroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 1000
velAsteroide = 0

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el ateroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 1000
velAsteroide = 25

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el ateroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Busquen el ateroide en el cielo

# %%
tamAsteroide = 1000
velAsteroide = 25

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Busquen el asteroide en el cielo

# %%
tamAsteroide = 1000
velAsteroide = 26

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 18
velAsteroide = 26

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 18
velAsteroide = 26

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 18
velAsteroide = 26

if velAsteroide > 25 and (tamAsteroide > 25 or tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 18
velAsteroide = 26

if velAsteroide > 25 and (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Busquen el asteroide en el cielo

# %%
tamAsteroide = 26
velAsteroide = 15

if velAsteroide > 25 and (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 1000
velAsteroide = 15

if velAsteroide > 25 and (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 1000
velAsteroide = 15

if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 1000
velAsteroide = 15

if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 999
velAsteroide = 15

if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 999
velAsteroide = 15

if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 1000
velAsteroide = 15

if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡La Tierra dejará de existir!

# %%
tamAsteroide = 1000
velAsteroide = 1


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡La Tierra dejará de existir!

# %%
tamAsteroide = 999
velAsteroide = 1


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 25
velAsteroide = 1


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 26
velAsteroide = 1


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 18
velAsteroide = 25


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# Busquen el asteroide en el cielo

# %%
tamAsteroide = 18
velAsteroide = 19


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# Continuen con sus actividades normales

# %%
tamAsteroide = 18
velAsteroide = 20


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# Busquen el asteroide en el cielo

# %%
tamAsteroide = 18
velAsteroide = 21


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# Busquen el asteroide en el cielo

# %%
tamAsteroide = 18
velAsteroide = 26


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!

# %%
tamAsteroide = 18
velAsteroide = 25


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# Busquen el asteroide en el cielo

# %%
tamAsteroide = 18
velAsteroide = 26


if velAsteroide > 25 or (tamAsteroide > 25 and tamAsteroide < 1000):
    print("¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!")
elif velAsteroide >= 20:
    print("Busquen el asteroide en el cielo")
elif tamAsteroide >=1000:
    print("¡La Tierra dejará de existir!")
else:
    print("Continuen con sus actividades normales")
# Out:
# ¡Alerta, se aproxima un asteroide demasiado rápido que puede causar daño!
